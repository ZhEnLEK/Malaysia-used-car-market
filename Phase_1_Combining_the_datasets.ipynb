# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
path, dirs, files = next(os.walk("C:/Users/Me/Desktop/motortrader dataset/dataset/"))

# %%
path
# Out:
# 'C:/Users/Me/Desktop/motortrader dataset/dataset/'

# %%
filecount = len(files)
filecount
# Out:
# 127

# %%
df_list = []

# %%
files[1]
# Out:
# 'motortrader101.csv'

# %%
df = pd.read_csv(path+files[1])
df.head(1)
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1631164402-1404  https://www.motortrader.com.my/usedcar/page/10...
#
#                                      usedcar  \
# 0  2015 NISSAN GRAND LIVINA 1.6L COMFORT (A)
#
#                                         usedcar-href  \
# 0  https://www.motortrader.com.my/usedcar/2106070...
#
#                                        items  \
# 0  2015 NISSAN GRAND LIVINA 1.6L COMFORT (A)
#
#                                                price  year  location    make  \
# 0  RM 40,999\n\n\n\n RM553 / Month\n\n ROADTAX RM...  2015  Selangor  NISSAN
#
#           model           variant            mileage  color transmission  \
# 0  GRAND LIVINA  1.6L COMFORT (A)  40,000 - 44,999km  Other    Automatic
#
#   engine displacement body type                                  dealer  \
# 0              1600cc       MPV  SLJ AUTOMOTIVE (M) SDN BHD (1296276-H)
#
# ...

# %%
# %%time
df_list = []
for i in range(filecount):
    temp_df = pd.read_csv(path+files[i])
    df_list.append(temp_df)
# Out:
# Wall time: 15.8 s

# %%
df_list[0].head(1)
# Out:
#   web-scraper-order                   web-scraper-start-url  \
# 0     1631133785-16  https://www.motortrader.com.my/usedcar
#
#                                              usedcar  \
# 0  2019 BMW X1 2.0 sDrive20i Dual Clutch (CKD) (A...
#
#                                         usedcar-href  \
# 0  https://www.motortrader.com.my/usedcar/2109080...
#
#                                                items  \
# 0  2019 BMW X1 2.0 sDrive20i Dual Clutch (CKD) (A...
#
#                                                price  year      location make  \
# 0  RM 176,888\n\n\n\n RM2,385 / Month\n\n ROADTAX...  2019  Kuala Lumpur  BMW
#
#   model                                            variant            mileage  \
# 0    X1  2.0 sDrive20i Dual Clutch (CKD) (A) TIPTOP CON...  55,000 - 59,999km
#
#   color transmission engine displacement body type  \
# 0  Blue    Automatic              2000cc       SUV
#
#                                 dealer  seller  pages  \
# ...

# %%
#df = pd.concat([df_list[0], df_list[1]], axis = 0)

# %%
filecount - 1
# Out:
# 126

# %%
# %%time
df = pd.DataFrame()

for i in range(filecount):
    #temp_df = pd.concat([df_list[i], df_list[i+1]], axis = 0)
    df = df.append(df_list[i] , ignore_index = True)
# Out:
# Wall time: 1.66 s

# %%
df.shape
# Out:
# (12572, 20)

# %%
df
# Out:
#       web-scraper-order                              web-scraper-start-url  \
# 0         1631133785-16             https://www.motortrader.com.my/usedcar
# 1         1631133944-55             https://www.motortrader.com.my/usedcar
# 2         1631134000-69             https://www.motortrader.com.my/usedcar
# 3         1631134044-82             https://www.motortrader.com.my/usedcar
# 4         1631134020-75             https://www.motortrader.com.my/usedcar
# ...                 ...                                                ...
# 12567   1631164058-1317  https://www.motortrader.com.my/usedcar/page/96...
# 12568   1631163912-1273  https://www.motortrader.com.my/usedcar/page/96...
# 12569   1631163998-1298  https://www.motortrader.com.my/usedcar/page/96...
# 12570   1631163983-1293  https://www.motortrader.com.my/usedcar/page/96...
# 12571   1631164095-1328  https://www.motortrader.com.my/usedcar/page/96...
#
#                                                  usedcar  \
# ...

# %%
#df.to_csv('motortraders.csv')

# %%
df_list[0]
# Out:
#    web-scraper-order                   web-scraper-start-url  \
# 0      1631133785-16  https://www.motortrader.com.my/usedcar
# 1      1631133944-55  https://www.motortrader.com.my/usedcar
# 2      1631134000-69  https://www.motortrader.com.my/usedcar
# 3      1631134044-82  https://www.motortrader.com.my/usedcar
# 4      1631134020-75  https://www.motortrader.com.my/usedcar
# ..               ...                                     ...
# 94     1631134053-85  https://www.motortrader.com.my/usedcar
# 95     1631133880-38  https://www.motortrader.com.my/usedcar
# 96     1631133762-10  https://www.motortrader.com.my/usedcar
# 97     1631133993-67  https://www.motortrader.com.my/usedcar
# 98     1631133814-21  https://www.motortrader.com.my/usedcar
#
#                                               usedcar  \
# 0   2019 BMW X1 2.0 sDrive20i Dual Clutch (CKD) (A...
# 1   2014 TOYOTA ALPHARD 2.4 X (FREE 2 YEARS CAR WA...
# 2   2009 TOYOTA ESTIMA 2.4 Aeras (Free 2 Years Car...
# ...

# %%
df1 = pd.concat(df_list, ignore_index = True)

# %%
df.shape
# Out:
# (12572, 20)

# %%
df1.shape
# Out:
# (12572, 20)

# %%
# %%time
import pandas as pd
import glob

path = r"C:\Users\Me\Desktop\motortrader dataset\dataset"
all_files = glob.glob(os.path.join(path, "*.csv"))


df = pd.concat((pd.read_csv(f, thousands = ',') for f in all_files), ignore_index= True)
# Out:
# Wall time: 1.09 s

# %%
df.shape
# Out:
# (12572, 20)

# %%
df
# Out:
#       web-scraper-order                              web-scraper-start-url  \
# 0         1631133785-16             https://www.motortrader.com.my/usedcar
# 1         1631133944-55             https://www.motortrader.com.my/usedcar
# 2         1631134000-69             https://www.motortrader.com.my/usedcar
# 3         1631134044-82             https://www.motortrader.com.my/usedcar
# 4         1631134020-75             https://www.motortrader.com.my/usedcar
# ...                 ...                                                ...
# 12567   1631164058-1317  https://www.motortrader.com.my/usedcar/page/96...
# 12568   1631163912-1273  https://www.motortrader.com.my/usedcar/page/96...
# 12569   1631163998-1298  https://www.motortrader.com.my/usedcar/page/96...
# 12570   1631163983-1293  https://www.motortrader.com.my/usedcar/page/96...
# 12571   1631164095-1328  https://www.motortrader.com.my/usedcar/page/96...
#
#                                                  usedcar  \
# ...

# %%
pd.set_option('display.max_columns', 100)

# %%
df.head(1)
# Out:
#   web-scraper-order                   web-scraper-start-url  \
# 0     1631133785-16  https://www.motortrader.com.my/usedcar
#
#                                              usedcar  \
# 0  2019 BMW X1 2.0 sDrive20i Dual Clutch (CKD) (A...
#
#                                         usedcar-href  \
# 0  https://www.motortrader.com.my/usedcar/2109080...
#
#                                                items  \
# 0  2019 BMW X1 2.0 sDrive20i Dual Clutch (CKD) (A...
#
#                                                price  year      location make  \
# 0  RM 176,888\n\n\n\n RM2,385 / Month\n\n ROADTAX...  2019  Kuala Lumpur  BMW
#
#   model                                            variant            mileage  \
# 0    X1  2.0 sDrive20i Dual Clutch (CKD) (A) TIPTOP CON...  55,000 - 59,999km
#
#   color transmission engine displacement body type  \
# 0  Blue    Automatic              2000cc       SUV
#
#                                 dealer  seller  pages  \
# ...

# %%
df['year']
# Out:
# 0        2019
# 1        2014
# 2        2009
# 3        2013
# 4        2016
#          ...
# 12567    2018
# 12568    2018
# 12569    2015
# 12570    2010
# 12571    2017
# Name: year, Length: 12572, dtype: int64

# %%
df['age'] = df['year'].apply(lambda x: 2021 - x)

# %%
df.head()
# Out:
#   web-scraper-order                   web-scraper-start-url  \
# 0     1631133785-16  https://www.motortrader.com.my/usedcar
# 1     1631133944-55  https://www.motortrader.com.my/usedcar
# 2     1631134000-69  https://www.motortrader.com.my/usedcar
# 3     1631134044-82  https://www.motortrader.com.my/usedcar
# 4     1631134020-75  https://www.motortrader.com.my/usedcar
#
#                                              usedcar  \
# 0  2019 BMW X1 2.0 sDrive20i Dual Clutch (CKD) (A...
# 1  2014 TOYOTA ALPHARD 2.4 X (FREE 2 YEARS CAR WA...
# 2  2009 TOYOTA ESTIMA 2.4 Aeras (Free 2 Years Car...
# 3  2013 TOYOTA VELLFIRE 3.5 V L EDITION FACELIFT ...
# 4  2016 BMW 3 SERIES 2016 BMW 320I SPORT LINE 2.0...
#
#                                         usedcar-href  \
# 0  https://www.motortrader.com.my/usedcar/2109080...
# 1  https://www.motortrader.com.my/usedcar/2010280...
# 2  https://www.motortrader.com.my/usedcar/2108210...
# 3  https://www.motortrader.com.my/usedcar/2104130...
# ...

# %%
loc_counts = df['location'].value_counts()
loc_counts
# Out:
# Kuala Lumpur       5943
# Selangor           5313
# Perak               649
# Johor               486
# Penang               63
# Melaka               37
# Kedah                19
# Negeri Sembilan      18
# Terengganu           13
# Sabah                10
# Sarawak               8
# Pahang                8
# Kelantan              5
# Name: location, dtype: int64

# %%
df['price']
# Out:
# 0        176,888
# 1        112,800
# 2         66,800
# 3        118,800
# 4        119,800
#           ...
# 12567     79,000
# 12568     43,300
# 12569     52,688
# 12570     89,688
# 12571    105,800
# Name: price, Length: 12572, dtype: object

# %%
df['price'].value_counts()
# Out:
# RM 28,800\n\n\n\n RM388 / Month\n\n ROADTAX RM 90.00          54
# RM 26,800\n\n\n\n RM361 / Month\n\n ROADTAX RM 90.00          46
# RM 29,800\n\n\n\n RM402 / Month\n\n ROADTAX RM 90.00          43
# RM 35,800\n\n\n\n RM483 / Month\n\n ROADTAX RM 90.00          40
# RM 30,800\n\n\n\n RM415 / Month\n\n ROADTAX RM 90.00          39
#                                                               ..
# RM 108,888\n\n\n\n RM1,468 / Month\n\n ROADTAX RM 480.00       1
# RM 43,800\n\n\n\n RM591 / Month\n\n ROADTAX RM 760.00          1
# RM 139,800\n\n\n\n RM1,885 / Month\n\n ROADTAX RM 2,440.00     1
# RM 129,800\n\n\n\n RM1,750 / Month\n\n ROADTAX RM 6,630.00     1
# RM 5,500\n\n\n ROADTAX RM 70.00                                1
# Name: price, Length: 6428, dtype: int64

# %%
df['price'] = df['price'].str.split(expand = True)[1]

# %%
df['price']
# Out:
# 0        176,888
# 1        112,800
# 2         66,800
# 3        118,800
# 4        119,800
#           ...
# 12567     79,000
# 12568     43,300
# 12569     52,688
# 12570     89,688
# 12571    105,800
# Name: price, Length: 12572, dtype: object

# %%
df['price'] = df['price'].str.replace(',', '').astype(int)

# %%
df['price']
# Out:
# 0        176888
# 1        112800
# 2         66800
# 3        118800
# 4        119800
#           ...
# 12567     79000
# 12568     43300
# 12569     52688
# 12570     89688
# 12571    105800
# Name: price, Length: 12572, dtype: int32

# %%
df['price'].isnull().value_counts()
# Out:
# False    12303
# Name: price, dtype: int64

# %%
df['mileage']
# Out:
# 0          55,000 - 59,999km
# 1        130,000 - 134,999km
# 2        125,000 - 129,999km
# 3        115,000 - 119,999km
# 4          70,000 - 74,999km
#                 ...
# 12567      20,000 - 24,999km
# 12568      20,000 - 24,999km
# 12569      65,000 - 69,999km
# 12570      80,000 - 84,999km
# 12571      60,000 - 64,999km
# Name: mileage, Length: 12572, dtype: object

# %%
df['mileage'] = df['mileage'].str.split(expand = True)[0]#.astype('float')  #.apply(lambda x : x + 2500)

# %%
#from unidecode import unidecode

df['mileage'] =df['mileage'].str.replace(',', '')

# %%
df['mileage'] = pd.to_numeric(df['mileage'], errors = 'coerce')
df = df.dropna(subset=['mileage'])

# %%
df['mileage'].isnull().value_counts()
# Out:
# False    12303
# Name: mileage, dtype: int64

# %%
df['mileage'] = df['mileage'].astype(int)
# Out:
# C:\Users\Me\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['mileage']
# Out:
# 0         55000
# 1        130000
# 2        125000
# 3        115000
# 4         70000
#           ...
# 12567     20000
# 12568     20000
# 12569     65000
# 12570     80000
# 12571     60000
# Name: mileage, Length: 12303, dtype: int32

# %%
df['make'].value_counts()
# Out:
# TOYOTA           2386
# HONDA            1527
# PROTON           1170
# PERODUA          1158
# MERCEDES-BENZ    1137
#                  ...
# Bus hino            1
# MORRIS              1
# Keeway              1
# Demak EX 90         1
# Honda               1
# Name: make, Length: 86, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2014    1410
# 2013    1406
# 2015    1300
# 2012    1287
# 2016    1012
# 2011     996
# 2010     820
# 2017     675
# 2009     600
# 2008     525
# 2018     522
# 2007     340
# 2006     319
# 2005     274
# 2019     240
# 2004     202
# 2003     138
# 2002      88
# 2000      67
# 2020      61
# 2001      60
# 1997      53
# 1999      38
# 1996      34
# 1995      23
# 1998      16
# 1994      10
# 2021       8
# 1987       7
# 1993       6
# 1990       5
# 1992       5
# 1991       4
# 1989       3
# 1968       2
# 1988       2
# 1950       1
# 1986       1
# 1978       1
# 1970       1
# 1983       1
# 1973       1
# 1967       1
# 1985       1
# 1982       1
# 1981       1
# 1971       1
# 1979       1
# 1976       1
# 1975       1
# Name: year, dtype: int64

# %%
df['body type'].value_counts()
# Out:
# Sedan          4800
# Hatchback      2077
# MPV            1779
# SUV            1719
# -               909
# Pickup          519
# Coupe           386
# Others          188
# Wagon           105
# Commercial       60
# Convertible      30
# Name: body type, dtype: int64

# %%
loc_counts.index
# Out:
# Index(['Kuala Lumpur', 'Selangor', 'Perak', 'Johor', 'Penang', 'Melaka',
#        'Kedah', 'Negeri Sembilan', 'Terengganu', 'Sabah', 'Sarawak', 'Pahang',
#        'Kelantan'],
#       dtype='object')

# %%
plt.bar(df['location'].value_counts().index, df['location'].value_counts())
# Out:
# <BarContainer object of 13 artists>
